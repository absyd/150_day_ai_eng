# %% [markdown]
# ## DAy-3 Token
#
# Tokenisation mechanics; context windows (8K/32K/200K); cost per token; when context fills up Token counter script + cost spreadsheet Anthropic tokeniser tool; OpenAI tokenizer playground Tokenise 10 different inputs; count tokens; calculate cost; find where 32K context breaks
#
# Tokenise 10 different inputs; count tokens; calculate cost; find where 32K context breaks

# %%
# !pip install tiktoken
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.3 MB/s eta 0:00:00
# ...

# %%
import tiktoken
enc = tiktoken.encoding_for_model("gpt-4o-mini")
enc
# Out:
# <Encoding 'o200k_base'>

# %%
dir(enc)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_core_bpe',
#  '_encode_bytes',
#  '_encode_only_native_bpe',
#  '_encode_single_piece',
#  '_mergeable_ranks',
#  '_pat_str',
#  '_special_tokens',
#  'decode',
#  'decode_batch',
#  'decode_bytes',
#  'decode_bytes_batch',
#  'decode_single_token_bytes',
#  'decode_tokens_bytes',
#  'decode_with_offsets',
#  'encode',
#  'encode_batch',
#  'encode_ordinary',
#  'encode_ordinary_batch',
#  'encode_single_token',
#  'encode_to_numpy',
#  'encode_with_unstable',
#  'eot_token',
#  'is_special_token',
#  'max_token_value',
# ...

# %%
tokens = enc.encode("Hello I Am Abu Sayed")
tokens
# Out:
# [13225, 357, 4820, 44705, 336, 19630]

# %%
import tiktoken
enc = tiktoken.encoding_for_model("gpt-5")
tokens = enc.encode("Fuck You")
tokens
# Out:
# [183714, 1608]

# %%
def count_token(text,model="gpt-4o-mini"):
  enc = tiktoken.encoding_for_model(model)
  tokens = enc.encode(text)
  return len(tokens)

# %%
text="Sayed is a very good boy and a ................"
count_token(text)
# Out:
# {'token_length': 10,
#  'tokens': [50, 19630, 382, 261, 1869, 1899, 8473, 326, 261, 194820]}

# %%
def count_chat_tokens(messages, model="gpt-4o-mini"):
    enc = tiktoken.encoding_for_model(model)
    tokens = 0
    for msg in messages:
        tokens += len(enc.encode(msg["content"]))
    return tokens

# %%
text = "hello " * 1000

# %%
count_token(text)
# Out:
# {'token_length': 10001,
#  'tokens': [24912,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
#   40617,
# ...

# %%
prompt="hello"
for i in range(1,100):
  prompt+="hello "*1000
  print("prompt : " ,prompt)
  print("peompt_len : " ,len(prompt))
  print(f"Step :{i} , text_size : {i*1000}")
  print("tokens : ",count_token(prompt))
